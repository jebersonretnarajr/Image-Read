# %% [markdown]
# <a href="https://colab.research.google.com/github/jebersonretnarajr/Image-Read/blob/master/image_read.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# !git clone https://github.com/jebersonretnarajr/Image-Read-Example.git
# Out:
# Cloning into 'Image-Read-Example'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 3024 (delta 3), reused 0 (delta 0), pack-reused 3006
# Receiving objects: 100% (3024/3024), 189.75 MiB | 51.51 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# Checking out files: 100% (3015/3015), done.

# %%
image = cv2.imread("Image-Read-Example/jetson_vali.jpg")
h=image.shape[0]
w=image.shape[1]
c=image.shape[2]

print(h,w,c)
# Out:
# 3024 4032 3

# %%
(b,g,r) = image[10,20]
print(b,g,r)
# Out:
# 172 175 180

# %%
plt.imshow(image)
